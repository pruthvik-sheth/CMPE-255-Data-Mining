# %%
# !kaggle competitions download -c california-house-prices
# Out:
# ...
#  98% 29.0M/29.5M [00:02<00:00, 18.8MB/s]
# 100% 29.5M/29.5M [00:02<00:00, 10.8MB/s]

# %%
# !pip install autogluon.tabular[TabularPredictor]
# Out:
# ...
# WARNING: autogluon-tabular 1.1.1 does not provide the extra 'tabularpredictor'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.8/234.8 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 119.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 105.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 8.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
# ...

# %%
# !pip uninstall scipy -y
# Out:
# Found existing installation: scipy 1.12.0
# Uninstalling scipy-1.12.0:
#   Successfully uninstalled scipy-1.12.0

# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor

# %%
# !unzip california-house-prices.zip
# Out:
# Archive:  california-house-prices.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
train_X = pd.read_csv("./train.csv")
eval_metric = 'roc_auc'
train_X.head()
# Out:
#    Id            Address  Sold Price  \
# 0   0        540 Pine Ln   3825000.0
# 1   1     1727 W 67th St    505000.0
# 2   2     28093 Pine Ave    140000.0
# 3   3  10750 Braddock Dr   1775000.0
# 4   4  7415 O Donovan Rd   1175000.0
#
#                                              Summary          Type  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...  SingleFamily
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...  SingleFamily
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...  SingleFamily
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...  SingleFamily
# 4  Beautiful 200 acre ranch land with several pas...    VacantLand
#
#    Year built                                       Heating  \
# 0      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1      1926.0                                   Combination
# 2      1958.0                                    Forced air
# 3      1947.0                                       Central
# ...

# %%
predictor = TabularPredictor(label="Sold Price", eval_metric=eval_metric, path="./", verbosity=3).fit(
    train_X, presets='best_quality', time_limit=300
)

results = predictor.fit_summary()
# Out:
# ...
# Verbosity: 3 (Detailed Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# GPU Count:          1
# Memory Avail:       10.31 GB / 12.67 GB (81.4%)
# Disk Space Avail:   75.18 GB / 112.64 GB (66.7%)
# ...
# Presets specified: ['best_quality']
# ============ fit kwarg info ============
# User Specified kwargs:
# {'auto_stack': True, 'num_bag_sets': 1}
# Full kwargs:
# {'_feature_generator_kwargs': None,
#  '_save_bag_folds': None,
#  'ag_args': None,
#  'ag_args_ensemble': None,
#  'ag_args_fit': None,
#  'auto_stack': True,
#  'calibrate': 'auto',
#  'ds_args': {'clean_up_fits': True,
#              'detection_time_frac': 0.25,
#              'enable_ray_logging': True,
#              'holdout_data': None,
#              'holdout_frac': 0.1111111111111111,
# ...

# %%
test_identity = pd.read_csv(directory+'test_identity.csv')
test_transaction = pd.read_csv(directory+'test_transaction.csv')
test_data = pd.merge(test_transaction, test_identity, on='TransactionID', how='left')  # same join applied to training files

y_predproba = predictor.predict_proba(test_data)
y_predproba.head(5)  # some example predicted fraud-probabilities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fee32f4d490d> in <cell line: 1>()
# ----> 1 test_identity = pd.read_csv(directory+'test_identity.csv')
#       2 test_transaction = pd.read_csv(directory+'test_transaction.csv')
#       3 test_data = pd.merge(test_transaction, test_identity, on='TransactionID', how='left')  # same join applied to training files
#       4
#       5 y_predproba = predictor.predict_proba(test_data)
#
# NameError: name 'directory' is not defined

# %%
predictor.positive_class
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-451c989c5489> in <cell line: 1>()
# ----> 1 predictor.positive_class
#
# NameError: name 'predictor' is not defined

# %%
predictor.class_labels  # classes in this list correspond to columns of predict_proba() output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-65e234265c8b> in <cell line: 1>()
# ----> 1 predictor.class_labels  # classes in this list correspond to columns of predict_proba() output
#
# NameError: name 'predictor' is not defined

# %%
y_predproba = predictor.predict_proba(test_data, as_multiclass=False)

# %%
submission = pd.read_csv(directory+'sample_submission.csv')
submission['isFraud'] = y_predproba
submission.head()
submission.to_csv(directory+'my_submission.csv', index=False)
